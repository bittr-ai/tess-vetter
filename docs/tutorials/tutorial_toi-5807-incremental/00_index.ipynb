# %% [markdown]
# # TOI-5807 incremental tutorial (index)
#
# This tutorial is split into small notebooks so you can iterate step-by-step.
#
# Design:
# - Each notebook is runnable on its own.
# - Each notebook includes **Expected Output** blocks and (when relevant) **pre-rendered plots** committed under `docs/tutorials/artifacts/tutorial_toi-5807-incremental/`.
# - Shared constants/helpers live in `toi5807_shared.py`.
#
# Steps:
# - `01_target_overview.ipynb`
# - `02_load_data_and_candidate.ipynb`
# - `03_phase_folded_transit_plot.ipynb`
# - `04_v01_odd_even.ipynb`
# - `05_v02_secondary.ipynb`
# - `06_v03_duration_consistency.ipynb`
# - `07_v04_depth_stability.ipynb`
# - `08_v05_v_shape.ipynb`
# - `09_v06_nearby_ebs.ipynb`
# - `10_v07_exofop.ipynb`
# - `11_v08_centroid_shift.ipynb`
# - `12_v09_difference_image.ipynb`
# - `13_v10_aperture_dependence.ipynb`
# - `14_v11_modshift.ipynb`
# - `15_v12_sweet.ipynb`
# - `16_v13_data_gaps.ipynb`
# - `17_v15_asymmetry.ipynb`
# - `18_v16_model_competition.ipynb`
# - `19_v17_ephemeris_reliability.ipynb`
# - `20_v18_sensitivity_sweep.ipynb`
# - `21_v19_alias_diagnostics.ipynb`
# - `22_v20_ghost_features.ipynb`
# - `23_v21_sector_consistency.ipynb`
# - `24_sector_gating_82_83.ipynb`
# - `25_gated_82_83_v16_model_competition.ipynb`
# - `26_gated_82_83_v17_ephemeris_reliability.ipynb`
# - `27_gated_82_83_v18_sensitivity_sweep.ipynb`
# - `28_gated_82_83_v19_alias_diagnostics.ipynb`
# - `29_gated_82_83_v11_modshift.ipynb`
# - `30_gated_82_83_v12_sweet.ipynb`
# - `31_gated_82_83_v01_v05_lc_checks.ipynb`
# - `32_gated_82_83_v13_v15_false_alarm_checks.ipynb`
# - `33_gated_82_83_adjust_detrend.ipynb`
# - `34_detrended_gated_82_83_rerun_suite.ipynb`
# - `35_gated_82_83_detrend_param_grid.ipynb`
# - `36_v22_triceratops_fpp.ipynb`
# - `37_v23_triceratops_fpp_with_contrast_curve.ipynb`
# - `38_v24_triceratops_fpp_sensitivity_grid.ipynb`
# - `39_v25_localization_consistency_82_83.ipynb`
# - `40_v26_dilution_and_radius_range.ipynb`
# - `41_v27_triceratops_standard_with_contrast_curve.ipynb`
# - `42_v28_current_status_summary.ipynb`

# %%
from pathlib import Path
import sys

tutorial_dir = Path('docs/tutorials/tutorial_toi-5807-incremental').resolve()
sys.path.insert(0, str(tutorial_dir))

import toi5807_shared as sh

sh.print_context(network=False)
