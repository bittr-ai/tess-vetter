# %% [markdown]
# # Step 1: Target overview (TOI-5807.01)
#
# Goal: define **stable, reproducible** inputs (IDs, ephemeris, stellar params, sky position) that every later step notebook uses.
#
# Notes:
# - We keep the ephemeris and stellar params frozen so tutorial outputs don’t drift over time.
# - The RA/Dec here match ExoFOP and the bundled TPF WCS header.

# %%
from pathlib import Path
import sys

tutorial_dir = Path('docs/tutorials/tutorial_toi-5807-incremental').resolve()
sys.path.insert(0, str(tutorial_dir))

import toi5807_shared as sh

NETWORK = False
sh.print_context(network=NETWORK)

# %% [markdown]
# <details>
# <summary><b>Expected Output</b></summary>
#
# ```text
# {
#   "coords_deg": {
#     "dec": 43.36068888888889,
#     "ra": 308.5672083333333
#   },
#   "ephemeris": {
#     "duration_hours": 4.046,
#     "period_days": 14.2423724,
#     "t0_btjd": 3540.26317
#   },
#   "network": false,
#   "stellar": {
#     "contamination": null,
#     "logg": 4.17,
#     "luminosity": null,
#     "mass": 1.47,
#     "metallicity": null,
#     "radius": 1.65,
#     "teff": 6816.0,
#     "tmag": null
#   },
#   "tic_id": 188646744,
#   "toi": "TOI-5807.01"
# }
# ```
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Analysis</b></summary>
#
# - **Why this matters:** these inputs drive transit masks, duration physics checks, and sky-position catalog queries.
# - **Sanity check:** RA/Dec match ExoFOP and the bundled TPF WCS header (so catalog cones land on the correct sky position).
#
# </details>
